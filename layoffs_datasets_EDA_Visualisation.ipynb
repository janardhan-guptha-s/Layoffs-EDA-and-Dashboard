# %% [markdown]
# ### In this notebook, I have explored the data, transformed the data to required format using Pandas, visualized the data using Plotly & found the below observations:
# 1. Top 10 companies that laid off
# 1. Top 3 companies that laid off year-wise
# 1. Top 3 locations where most layoffs happened year-wise
# 1. Top 20 companies that laid off x% of employees
# 1. Top 10 countries where most layoffs happened
# 1. Top 10 locations where most layoffs happened in USA
# 1. Top locations where most layoffs happened in India
# 1. Relationship between funds received and layoffs
# 1. In which stage of the company had the most lay offs?
# 1. Which industry had the most layoffs?
# 1. Total layoffs year-wise
# 1. Year wise layoffs according to country

# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Let`s dive into the data

# %%
df = pd.read_csv('layoffs.csv')
df
# Out:
#             company        location        industry  total_laid_off  \
# 0         Northvolt       Stockholm          Energy          1600.0
# 1             Drata       San Diego        Security            40.0
# 2              Moov     Cedar Falls         Finance            50.0
# 3      FreightWaves     Chattanooga       Logistics            16.0
# 4                F5         Seattle        Security             NaN
# ...             ...             ...             ...             ...
# 3801        Service     Los Angeles          Travel             NaN
# 3802   HopSkipDrive     Los Angeles  Transportation             8.0
# 3803    Panda Squad     SF Bay Area        Consumer             6.0
# 3804  Tamara Mellon     Los Angeles          Retail            20.0
# 3805       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date           stage        country  \
# 0                    0.20  2025-09-23         Unknown         Sweden
# 1                    0.09  2024-09-26        Series C  United States
# 2                     NaN  2024-09-25        Series B  United States
# 3                     NaN  2024-09-24  Private Equity  United States
# 4                     NaN  2024-09-24        Post-IPO  United States
# ...                   ...         ...             ...            ...
# 3801                 1.00  2020-03-16            Seed  United States
# 3802                 0.10  2020-03-13         Unknown  United States
# 3803                 0.75  2020-03-13            Seed  United States
# 3804                 0.40  2020-03-12        Series C  United States
# 3805                  NaN  2020-03-11        Series A  United States
#
#       funds_raised
# 0          13800.0
# 1            328.0
# 2             77.0
# 3             92.0
# 4              NaN
# ...            ...
# 3801           5.1
# 3802          45.0
# 3803           1.0
# 3804          90.0
# 3805          12.0
#
# [3806 rows x 9 columns]

# %%
# Total companies
df.company.nunique()
len(df.company.unique())
# Out:
# 2681
# 2681

# %%
# But shape is 1634
df.shape
# Out:
# (3806, 9)

# %% [markdown]
# ### Total company count and the Shape is 3806. Let's see duplicate companies

# %%
df.company.value_counts().sort_values(ascending=False)
# Out:
# Google           12
# Amazon           12
# Microsoft         9
# Rivian            8
# Spotify           7
#                  ..
# Lacework          1
# Dazn              1
# Truck It In       1
# VTEX              1
# Tamara Mellon     1
# Name: company, Length: 2681, dtype: int64

# %%
df.company.value_counts() > 1
# Out:
# Google            True
# Amazon            True
# Microsoft         True
# Rivian            True
# Spotify           True
#                  ...
# Color Health     False
# iFood            False
# Truckstop.com    False
# Kandela          False
# Tamara Mellon    False
# Name: company, Length: 2681, dtype: bool

# %%
df[df.company == "Uber"]
# Out:
#      company     location        industry  total_laid_off  \
# 1036    Uber  SF Bay Area  Transportation           200.0
# 2449    Uber      Vilnius  Transportation            60.0
# 3282    Uber    Amsterdam  Transportation           225.0
# 3314    Uber    Bengaluru  Transportation           600.0
# 3333    Uber  SF Bay Area  Transportation          3000.0
# 3379    Uber  SF Bay Area  Transportation          3700.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# 1036                  NaN  2023-06-21  Post-IPO  United States       25200.0
# 2449                  NaN  2022-09-07  Post-IPO      Lithuania       24700.0
# 3282                 0.25  2020-06-12  Post-IPO    Netherlands       24700.0
# 3314                 0.23  2020-05-26  Post-IPO          India       24700.0
# 3333                 0.13  2020-05-18  Post-IPO  United States       24700.0
# 3379                 0.14  2020-05-06  Post-IPO  United States       24700.0

# %% [markdown]
# ### Company can lay off on different dates. So, there are duplicate company values

# %%
df.groupby('company').sum()
# Out:
#                   total_laid_off  percentage_laid_off  funds_raised
# company
#  E Inc.                      0.0                 0.00           0.0
#  F-Secure                   70.0                 0.00           0.0
#  Included Health             0.0                 0.06         272.0
# #Paid                       19.0                 0.17          21.0
# &Open                        9.0                 0.09          35.0
# ...                          ...                  ...           ...
# kununu                       0.0                 0.00           0.0
# mPharma                    150.0                 0.00          90.0
# nCino                      100.0                 0.07        1100.0
# tZero                        0.0                 0.00         472.0
# uShip                       65.0                 0.37          69.0
#
# [2681 rows x 3 columns]

# %%
df.groupby('company').sum().loc['Uber',:]
# Out:
# total_laid_off           7785.00
# percentage_laid_off         0.75
# funds_raised           148700.00
# Name: Uber, dtype: float64

# %% [markdown]
# ### Find NaNs

# %%
df.head(2)
df.isnull().sum()
# Out:
#      company   location  industry  total_laid_off  percentage_laid_off  \
# 0  Northvolt  Stockholm    Energy          1600.0                 0.20
# 1      Drata  San Diego  Security            40.0                 0.09
#
#          date     stage        country  funds_raised
# 0  2025-09-23   Unknown         Sweden       13800.0
# 1  2024-09-26  Series C  United States         328.0
# company                   0
# location                  1
# industry                  1
# total_laid_off         1319
# percentage_laid_off    1369
# date                      0
# stage                     7
# country                   0
# funds_raised            415
# dtype: int64

# %% [markdown]
# ### Fill NaNs with 0s

# %%
df.fillna(value=0,inplace=True)
df.isnull().sum()
# Out:
# company                0
# location               0
# industry               0
# total_laid_off         0
# percentage_laid_off    0
# date                   0
# stage                  0
# country                0
# funds_raised           0
# dtype: int64

# %%
df.head()
# Out:
#         company     location   industry  total_laid_off  percentage_laid_off  \
# 0     Northvolt    Stockholm     Energy          1600.0                 0.20
# 1         Drata    San Diego   Security            40.0                 0.09
# 2          Moov  Cedar Falls    Finance            50.0                  NaN
# 3  FreightWaves  Chattanooga  Logistics            16.0                  NaN
# 4            F5      Seattle   Security             NaN                  NaN
#
#          date           stage        country  funds_raised
# 0  2025-09-23         Unknown         Sweden       13800.0
# 1  2024-09-26        Series C  United States         328.0
# 2  2024-09-25        Series B  United States          77.0
# 3  2024-09-24  Private Equity  United States          92.0
# 4  2024-09-24        Post-IPO  United States           NaN

# %% [markdown]
# ## Top 10 companies that laid off

# %%
top10_idx = df['total_laid_off'].sort_values(ascending=False)[:10].index
top10_idx
df.iloc[top10_idx,:]
px.bar(df.iloc[top10_idx,:],x='company',y='total_laid_off', text='total_laid_off',title='Top 10 companies that laid off')
# Out:
# Int64Index([76, 241, 1707, 2191, 1382, 2123, 1740, 1365, 1452, 1882], dtype='int64')
#         company     location        industry  total_laid_off  \
# 76        Intel  SF Bay Area        Hardware         15000.0
# 241       Tesla       Austin  Transportation         14000.0
# 1707     Google  SF Bay Area        Consumer         12000.0
# 2191       Meta  SF Bay Area        Consumer         11000.0
# 1382       Meta  SF Bay Area        Consumer         10000.0
# 2123     Amazon      Seattle          Retail         10000.0
# 1740  Microsoft      Seattle           Other         10000.0
# 1365     Amazon      Seattle          Retail          9000.0
# 1452   Ericsson    Stockholm           Other          8500.0
# 1882     Amazon      Seattle          Retail          8000.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# 76                   0.15  2024-08-01  Post-IPO  United States          12.0
# 241                  0.10  2024-04-15  Post-IPO  United States       20200.0
# 1707                 0.06  2023-01-20  Post-IPO  United States          26.0
# 2191                 0.13  2022-11-09  Post-IPO  United States       26000.0
# 1382                  NaN  2023-03-14  Post-IPO  United States       26000.0
# 2123                 0.03  2022-11-16  Post-IPO  United States         108.0
# 1740                 0.05  2023-01-18  Post-IPO  United States           1.0
# 1365                  NaN  2023-03-20  Post-IPO  United States         108.0
# 1452                 0.08  2023-02-24  Post-IPO         Sweden         663.0
# 1882                 0.02  2023-01-04  Post-IPO  United States         108.0
# <div>                            <div id="d5c0b556-22c3-42e7-9965-c1675b8a16c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5c0b556-22c3-42e7-9965-c1675b8a16c5")) {                    Plotly.newPlot(                        "d5c0b556-22c3-42e7-9965-c1675b8a16c5",                        [{"alignmentgroup":"True","hovertemplate":"company=%{x}<br>total_laid_off=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[15000.0,14000.0,12000.0,11000.0,10000.0,10000.0,10000.0,9000.0,8500.0,8000.0],"textposition":"auto","x":["Intel","Tesla","Google","Meta","Meta","Amazon","Microsoft","Amazon","Ericsson","Amazon"],"xaxis":"x","y":[15000.0,14000.0,12000.0,11000.0,10000.0,10000.0,10000.0,9000.0,8500.0,8000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern" ...

# %% [markdown]
# ### This is wrong, Meta and Amazon are repeated. Need to clean the data such that there are no duplicate companies.

# %%
df_no_dup = df.copy()

# %%
# Top 10 companies that laid off 
df_no_dup.groupby('company').total_laid_off.sum().sort_values(ascending=False)[:10]
px.bar(df_no_dup.groupby('company').total_laid_off.sum().sort_values(ascending=False)[:10],text_auto=True,title='Top 10 companies that laid off',
      labels={"x":"Company","y":"Layoffs"})
# Out:
# company
# Amazon        27840.0
# Meta          21000.0
# Intel         16057.0
# Microsoft     14708.0
# Tesla         14500.0
# Cisco         14300.0
# Google        13472.0
# Dell          12650.0
# Salesforce    11140.0
# SAP           11000.0
# Name: total_laid_off, dtype: float64
# <div>                            <div id="5975b090-0f15-4f34-91e2-948c3e836935" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5975b090-0f15-4f34-91e2-948c3e836935")) {                    Plotly.newPlot(                        "5975b090-0f15-4f34-91e2-948c3e836935",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_laid_off<br>company=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_laid_off","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"total_laid_off","offsetgroup":"total_laid_off","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amazon","Meta","Intel","Microsoft","Tesla","Cisco","Google","Dell","Salesforce","SAP"],"xaxis":"x","y":[27840.0,21000.0,16057.0,14708.0,14500.0,14300.0,13472.0,12650.0,11140.0,11000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fill ...

# %% [markdown]
# ### This is correct :)

# %% [markdown]
# # Top 3 companies that laid off year-wise

# %%
df.head()
# Out:
#         company       location   industry  total_laid_off  \
# 1         Drata      San Diego   Security            40.0
# 2          Moov    Cedar Falls    Finance            50.0
# 3  FreightWaves    Chattanooga  Logistics            16.0
# 4            F5        Seattle   Security             NaN
# 5           Olo  New York City       Food             NaN
#
#    percentage_laid_off        date           stage        country  \
# 1                 0.09  2024-09-26        Series C  United States
# 2                  NaN  2024-09-25        Series B  United States
# 3                  NaN  2024-09-24  Private Equity  United States
# 4                  NaN  2024-09-24        Post-IPO  United States
# 5                 0.09  2024-09-23        Post-IPO  United States
#
#    funds_raised  Year
# 1         328.0  2024
# 2          77.0  2024
# 3          92.0  2024
# 4           NaN  2024
# 5         184.0  2024

# %%
df = df[df['date'] != '2025-09-23'] # 2025 delete

# %%
df.head()
# Out:
#         company       location   industry  total_laid_off  \
# 1         Drata      San Diego   Security            40.0
# 2          Moov    Cedar Falls    Finance            50.0
# 3  FreightWaves    Chattanooga  Logistics            16.0
# 4            F5        Seattle   Security             NaN
# 5           Olo  New York City       Food             NaN
#
#    percentage_laid_off        date           stage        country  \
# 1                 0.09  2024-09-26        Series C  United States
# 2                  NaN  2024-09-25        Series B  United States
# 3                  NaN  2024-09-24  Private Equity  United States
# 4                  NaN  2024-09-24        Post-IPO  United States
# 5                 0.09  2024-09-23        Post-IPO  United States
#
#    funds_raised  Year
# 1         328.0  2024
# 2          77.0  2024
# 3          92.0  2024
# 4           NaN  2024
# 5         184.0  2024

# %% [markdown]
# ### Need to filter only year from date column

# %%
df["Year"] = df["date"].map(lambda x : x[:4])
df
# Out:
#             company        location        industry  total_laid_off  \
# 1             Drata       San Diego        Security            40.0
# 2              Moov     Cedar Falls         Finance            50.0
# 3      FreightWaves     Chattanooga       Logistics            16.0
# 4                F5         Seattle        Security             NaN
# 5               Olo   New York City            Food             NaN
# ...             ...             ...             ...             ...
# 3801        Service     Los Angeles          Travel             NaN
# 3802   HopSkipDrive     Los Angeles  Transportation             8.0
# 3803    Panda Squad     SF Bay Area        Consumer             6.0
# 3804  Tamara Mellon     Los Angeles          Retail            20.0
# 3805       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date           stage        country  \
# 1                    0.09  2024-09-26        Series C  United States
# 2                     NaN  2024-09-25        Series B  United States
# 3                     NaN  2024-09-24  Private Equity  United States
# 4                     NaN  2024-09-24        Post-IPO  United States
# 5                    0.09  2024-09-23        Post-IPO  United States
# ...                   ...         ...             ...            ...
# 3801                 1.00  2020-03-16            Seed  United States
# 3802                 0.10  2020-03-13         Unknown  United States
# 3803                 0.75  2020-03-13            Seed  United States
# 3804                 0.40  2020-03-12        Series C  United States
# 3805                  NaN  2020-03-11        Series A  United States
#
#       funds_raised  Year
# 1            328.0  2024
# 2             77.0  2024
# 3             92.0  2024
# 4              NaN  2024
# 5            184.0  2024
# ...            ...   ...
# 3801           5.1  2020
# 3802          45.0  2020
# 3803           1.0  2020
# 3804          90.0  2020
# 3805          12.0  2020
#
# [3805 rows x 10 columns]

# %%
df.groupby(["Year"],sort=False)["total_laid_off"].max()
# Out:
# Year
# 2024    15000.0
# 2023    12000.0
# 2022    11000.0
# 2021     2434.0
# 2020     4375.0
# Name: total_laid_off, dtype: float64

# %%
df.groupby(['Year','company']).total_laid_off.agg([max])
# Out:
#                  max
# Year company
# 2020 1stdibs    70.0
#      Acko       45.0
#      Acorns     50.0
#      Actifio    54.0
#      AdRoll    210.0
# ...              ...
# 2024 Zuora       NaN
#      Zwift       NaN
#      eBay     1000.0
#      iCIMS      69.0
#      iRobot    350.0
#
# [3351 rows x 1 columns]

# %%
top_3_year_wise = df.groupby(['Year','company']).total_laid_off.agg([max])
top_3_year_wise
# Out:
#                  max
# Year company
# 2020 1stdibs    70.0
#      Acko       45.0
#      Acorns     50.0
#      Actifio    54.0
#      AdRoll    210.0
# ...              ...
# 2024 Zuora       NaN
#      Zwift       NaN
#      eBay     1000.0
#      iCIMS      69.0
#      iRobot    350.0
#
# [3351 rows x 1 columns]

# %%
top_3_year_wise["max"]
top_3_year_wise["max"].groupby(['Year'],group_keys=False)
# Out:
# Year  company
# 2020  1stdibs      70.0
#       Acko         45.0
#       Acorns       50.0
#       Actifio      54.0
#       AdRoll      210.0
#                   ...
# 2024  Zuora         NaN
#       Zwift         NaN
#       eBay       1000.0
#       iCIMS        69.0
#       iRobot      350.0
# Name: max, Length: 3351, dtype: float64

# %%
# Got it from https://stackoverflow.com/questions/27842613/pandas-groupby-then-sort-within-groups 
g = top_3_year_wise["max"].groupby(['Year'],group_keys=False)
top_3_year_wise2 = g.apply(lambda x : x.sort_values(ascending=False).head(3)) # Selecting each group, sorting & taking top 3
top_3_year_wise2
# Out:
# Year  company
# 2020  Booking.com     4375.0
#       Uber            3700.0
#       Groupon         2800.0
# 2021  Katerra         2434.0
#       Zillow          2000.0
#       Instacart       1877.0
# 2022  Meta           11000.0
#       Amazon         10000.0
#       Cisco           4100.0
# 2023  Google         12000.0
#       Meta           10000.0
#       Microsoft      10000.0
# 2024  Intel          15000.0
#       Tesla          14000.0
#       SAP             8000.0
# Name: max, dtype: float64

# %%
g.nlargest(3) # Get top 3 in each group ( inbuilt method )
# Out:
# Year  company
# 2020  Booking.com     4375.0
#       Uber            3700.0
#       Groupon         2800.0
# 2021  Katerra         2434.0
#       Zillow          2000.0
#       Instacart       1877.0
# 2022  Meta           11000.0
#       Amazon         10000.0
#       Cisco           4100.0
# 2023  Google         12000.0
#       Meta           10000.0
#       Microsoft      10000.0
# 2024  Intel          15000.0
#       Tesla          14000.0
#       SAP             8000.0
# Name: max, dtype: float64

# %%
top_3_year_wise2.index
top_3_year_wise2.values
# Out:
# MultiIndex([('2020', 'Booking.com'),
#             ('2020',        'Uber'),
#             ('2020',     'Groupon'),
#             ('2021',     'Katerra'),
#             ('2021',      'Zillow'),
#             ('2021',   'Instacart'),
#             ('2022',        'Meta'),
#             ('2022',      'Amazon'),
#             ('2022',       'Cisco'),
#             ('2023',      'Google'),
#             ('2023',        'Meta'),
#             ('2023',   'Microsoft'),
#             ('2024',       'Intel'),
#             ('2024',       'Tesla'),
#             ('2024',         'SAP')],
#            names=['Year', 'company'])
# array([ 4375.,  3700.,  2800.,  2434.,  2000.,  1877., 11000., 10000.,
#         4100., 12000., 10000., 10000., 15000., 14000.,  8000.])

# %%
top_3_year_wise3 = pd.DataFrame()
top_3_year_wise3["total_laid_off"] = top_3_year_wise2.values
top_3_year_wise3
# Out:
#     total_laid_off
# 0           4375.0
# 1           3700.0
# 2           2800.0
# 3           2434.0
# 4           2000.0
# 5           1877.0
# 6          11000.0
# 7          10000.0
# 8           4100.0
# 9          12000.0
# 10         10000.0
# 11         10000.0
# 12         15000.0
# 13         14000.0
# 14          8000.0

# %%
y = []
c = []
for i,j in top_3_year_wise2.index:
    y.append(i)
    c.append(j)
top_3_year_wise3["Year"] = y
top_3_year_wise3["Company"] = c
top_3_year_wise3
# Out:
#     total_laid_off  Year      Company
# 0           4375.0  2020  Booking.com
# 1           3700.0  2020         Uber
# 2           2800.0  2020      Groupon
# 3           2434.0  2021      Katerra
# 4           2000.0  2021       Zillow
# 5           1877.0  2021    Instacart
# 6          11000.0  2022         Meta
# 7          10000.0  2022       Amazon
# 8           4100.0  2022        Cisco
# 9          12000.0  2023       Google
# 10         10000.0  2023         Meta
# 11         10000.0  2023    Microsoft
# 12         15000.0  2024        Intel
# 13         14000.0  2024        Tesla
# 14          8000.0  2024          SAP

# %%
px.bar(top_3_year_wise3,x='Year',y='total_laid_off',color='Company', title='Top 3 companies that laid off year-wise',text_auto=True)
# Out:
# <div>                            <div id="9fd9b0a8-9314-4f15-b556-fda4599f4947" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fd9b0a8-9314-4f15-b556-fda4599f4947")) {                    Plotly.newPlot(                        "9fd9b0a8-9314-4f15-b556-fda4599f4947",                        [{"alignmentgroup":"True","hovertemplate":"Company=Booking.com<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Booking.com","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Booking.com","offsetgroup":"Booking.com","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020"],"xaxis":"x","y":[4375.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Uber<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Uber","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Uber","offsetgroup":"Uber","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020"],"xaxis":"x","y":[3700.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Groupon<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Groupon","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Groupon","offsetgroup":"Groupon","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020"],"xaxis":"x","y":[2800.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Katerra<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Katerra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Katerra","offsetgroup":"Katerra","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021"],"xaxis":"x","y":[2434.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Zillow<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Zillow","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Zillow","offsetgroup":"Zillow","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021"],"xaxis":"x","y":[2000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Instacart<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Instacart","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Instacart","offsetgroup":"Instacart","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021"],"xaxis":"x","y":[1877.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Meta<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Meta","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Meta","offsetgroup":"Meta","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2022","2023"],"xaxis":"x","y":[11000.0,10000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Amazon<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Amazon","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Amazon","offsetgroup":"Amazon","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2022"],"xaxis":"x","y":[10000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Cisco<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Cisco","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Cisco","offsetgroup":"Cisco","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2022"],"xaxis":"x","y":[4100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=Google<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Googl ...

# %% [markdown]
# ## Top 3 locations where most layoffs happened year-wise

# %%
df.head()
top_3_loction_year_wise = df.groupby(["Year","location"]).total_laid_off.agg([max])
top_3_loction_year_wise
# Out:
#         company       location   industry  total_laid_off  \
# 1         Drata      San Diego   Security            40.0
# 2          Moov    Cedar Falls    Finance            50.0
# 3  FreightWaves    Chattanooga  Logistics            16.0
# 4            F5        Seattle   Security             NaN
# 5           Olo  New York City       Food             NaN
#
#    percentage_laid_off        date           stage        country  \
# 1                 0.09  2024-09-26        Series C  United States
# 2                  NaN  2024-09-25        Series B  United States
# 3                  NaN  2024-09-24  Private Equity  United States
# 4                  NaN  2024-09-24        Post-IPO  United States
# 5                 0.09  2024-09-23        Post-IPO  United States
#
#    funds_raised  Year
# 1         328.0  2024
# 2          77.0  2024
# 3          92.0  2024
# 4           NaN  2024
# 5         184.0  2024
#                          max
# Year location
# 2020 Ahmedabad         500.0
#      Amsterdam        4375.0
#      Ann Arbor          40.0
#      Atlanta           150.0
#      Austin            451.0
# ...                      ...
# 2024 Washington D.C.    50.0
#      Waterloo         1200.0
#      Winnipeg          800.0
#      Xi'an               NaN
#      Yavne             100.0
#
# [510 rows x 1 columns]

# %%
g1 = top_3_loction_year_wise.groupby(["Year"],group_keys=False)
top_3_loction_year_wise2 = g1.apply(lambda x : x.sort_values(["max"], ascending=False).head(3)) 
top_3_loction_year_wise2
# Out:
#                       max
# Year location
# 2020 Amsterdam     4375.0
#      SF Bay Area   3700.0
#      Chicago       2800.0
# 2021 SF Bay Area   2434.0
#      Seattle       2000.0
#      Mumbai        1800.0
# 2022 SF Bay Area  11000.0
#      Seattle      10000.0
#      Amsterdam     4000.0
# 2023 SF Bay Area  12000.0
#      Seattle      10000.0
#      Stockholm     8500.0
# 2024 SF Bay Area  15000.0
#      Austin       14000.0
#      Walldorf      8000.0

# %%
top_3_loction_year_wise2.values.reshape(15,).tolist()
# Out:
# [4375.0,
#  3700.0,
#  2800.0,
#  2434.0,
#  2000.0,
#  1800.0,
#  11000.0,
#  10000.0,
#  4000.0,
#  12000.0,
#  10000.0,
#  8500.0,
#  15000.0,
#  14000.0,
#  8000.0]

# %%
top_3_loction_year_wise3 = pd.DataFrame()
top_3_loction_year_wise3["total_laid_off"] = top_3_loction_year_wise2.values.reshape(15,).tolist()
top_3_loction_year_wise3
# Out:
#     total_laid_off
# 0           4375.0
# 1           3700.0
# 2           2800.0
# 3           2434.0
# 4           2000.0
# 5           1800.0
# 6          11000.0
# 7          10000.0
# 8           4000.0
# 9          12000.0
# 10         10000.0
# 11          8500.0
# 12         15000.0
# 13         14000.0
# 14          8000.0

# %%
y = []
l = []
for i,j in top_3_loction_year_wise2.index:
    y.append(i)
    l.append(j)
top_3_loction_year_wise3["Year"] = y
top_3_loction_year_wise3["Location"] = l
top_3_loction_year_wise3
# Out:
#     total_laid_off  Year     Location
# 0           4375.0  2020    Amsterdam
# 1           3700.0  2020  SF Bay Area
# 2           2800.0  2020      Chicago
# 3           2434.0  2021  SF Bay Area
# 4           2000.0  2021      Seattle
# 5           1800.0  2021       Mumbai
# 6          11000.0  2022  SF Bay Area
# 7          10000.0  2022      Seattle
# 8           4000.0  2022    Amsterdam
# 9          12000.0  2023  SF Bay Area
# 10         10000.0  2023      Seattle
# 11          8500.0  2023    Stockholm
# 12         15000.0  2024  SF Bay Area
# 13         14000.0  2024       Austin
# 14          8000.0  2024     Walldorf

# %%
px.bar(top_3_loction_year_wise3,x='Year',y='total_laid_off',color='Location', title='Top 3 locations year-wise where layoffs happened the most',text_auto=True)
# Out:
# <div>                            <div id="e7de541a-ed75-4c95-a86e-733aaac1b5fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7de541a-ed75-4c95-a86e-733aaac1b5fe")) {                    Plotly.newPlot(                        "e7de541a-ed75-4c95-a86e-733aaac1b5fe",                        [{"alignmentgroup":"True","hovertemplate":"Location=Amsterdam<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Amsterdam","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Amsterdam","offsetgroup":"Amsterdam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020","2022"],"xaxis":"x","y":[4375.0,4000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=SF Bay Area<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"SF Bay Area","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SF Bay Area","offsetgroup":"SF Bay Area","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020","2021","2022","2023","2024"],"xaxis":"x","y":[3700.0,2434.0,11000.0,12000.0,15000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=Chicago<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Chicago","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Chicago","offsetgroup":"Chicago","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020"],"xaxis":"x","y":[2800.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=Seattle<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Seattle","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Seattle","offsetgroup":"Seattle","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021","2022","2023"],"xaxis":"x","y":[2000.0,10000.0,10000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=Mumbai<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Mumbai","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mumbai","offsetgroup":"Mumbai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021"],"xaxis":"x","y":[1800.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=Stockholm<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Stockholm","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Stockholm","offsetgroup":"Stockholm","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2023"],"xaxis":"x","y":[8500.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=Austin<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Austin","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Austin","offsetgroup":"Austin","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2024"],"xaxis":"x","y":[14000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=Walldorf<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Walldorf","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Walldorf","offsetgroup":"Walldorf","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2024"],"xaxis":"x","y":[8000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777 ...

# %% [markdown]
# ## Top 20 companies that laid off x% of employees

# %%
(df_no_dup.groupby('company').percentage_laid_off.sum().sort_values(ascending=False)[:20])*100
px.bar((df_no_dup.groupby('company').percentage_laid_off.sum().sort_values(ascending=False)[:20])*100,text_auto=True,title='Top 20 companies that laid off x% of employees')
# Out:
# company
# FrontRow        295.0
# Zeus Living     226.0
# Cue Health      222.0
# Joonko          200.0
# Service         200.0
# ReshaMandi      180.0
# Airy Rooms      170.0
# Zume            167.0
# Medly           166.0
# Pollen          164.0
# Shift           164.0
# Rubius          157.0
# RenoRun         155.0
# IronNet         152.0
# Propzy          150.0
# The Wing        150.0
# InVision        150.0
# Kenko Health    140.0
# Dunzo           138.0
# Nori            137.0
# Name: percentage_laid_off, dtype: float64
# <div>                            <div id="f884a9e0-608d-4803-b061-2f300b7e109e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f884a9e0-608d-4803-b061-2f300b7e109e")) {                    Plotly.newPlot(                        "f884a9e0-608d-4803-b061-2f300b7e109e",                        [{"alignmentgroup":"True","hovertemplate":"variable=percentage_laid_off<br>company=%{x}<br>value=%{y}<extra></extra>","legendgroup":"percentage_laid_off","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"percentage_laid_off","offsetgroup":"percentage_laid_off","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["FrontRow","Zeus Living","Cue Health","Joonko","Service","ReshaMandi","Airy Rooms","Zume","Medly","Pollen","Shift","Rubius","RenoRun","IronNet","Propzy","The Wing","InVision","Kenko Health","Dunzo","Nori"],"xaxis":"x","y":[295.0,225.99999999999997,221.99999999999997,200.0,200.0,180.0,170.00000000000003,167.0,166.0,164.0,164.0,157.0,155.0,152.0,150.0,150.0,150.0,140.0,138.0,137.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar ...

# %%
# Country wise lay offs percentage
country_group  = df.groupby(['country']).sum().sort_values(['total_laid_off'],ascending=False)
country_group.head(10)
# Out:
#                 total_laid_off  percentage_laid_off  funds_raised
# country
# United States         448358.0             433.3225  1.893594e+06
# India                  55759.0              59.0500  2.258846e+05
# Germany                28153.0              18.8750  8.253298e+04
# United Kingdom         20769.0              29.0600  7.577044e+04
# Netherlands            18705.0               3.2900  3.094400e+04
# Sweden                 13659.0               4.5000  2.839400e+04
# Canada                 12422.0              25.1300  2.479530e+04
# Brazil                 11323.0              12.4300  3.669870e+04
# China                   8190.0               1.5100  1.020670e+05
# Singapore               7440.0              10.0500  5.347098e+04

# %% [markdown]
# ## Top 10 countries where most layoffs happened

# %%
px.bar(country_group.iloc[:10,0],text_auto=True,title='Top 10 countries where most layoffs happened')
# Out:
# <div>                            <div id="1fb014e4-b4ac-452d-92aa-05c4d7d34718" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fb014e4-b4ac-452d-92aa-05c4d7d34718")) {                    Plotly.newPlot(                        "1fb014e4-b4ac-452d-92aa-05c4d7d34718",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_laid_off<br>country=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_laid_off","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"total_laid_off","offsetgroup":"total_laid_off","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["United States","India","Germany","United Kingdom","Netherlands","Sweden","Canada","Brazil","China","Singapore"],"xaxis":"x","y":[448358.0,55759.0,28153.0,20769.0,18705.0,13659.0,12422.0,11323.0,8190.0,7440.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","widt ...

# %% [markdown]
# ## Top 10 locations where most layoffs happened in USA

# %%
# Only USA location wise
location_usa_group  = df[df.country == "United States"].groupby(['location']).sum().sort_values(['total_laid_off'],ascending=False)
location_usa_group
# Out:
#                total_laid_off  percentage_laid_off  funds_raised
# location
# SF Bay Area          209618.0             165.5575     1189757.3
# Seattle               54554.0              23.6900       43151.2
# New York City         37457.0              73.5100      156248.2
# Austin                33583.0              11.3500       72654.3
# Boston                19372.0              29.7900       60667.0
# ...                       ...                  ...           ...
# Huntsville                0.0               0.0000           0.0
# Providence                0.0               0.1500         946.0
# Houston                   0.0               1.0000          22.0
# Richmond                  0.0               0.0000         221.0
# Alamosa                   0.0               0.0000         306.0
#
# [113 rows x 3 columns]

# %%
# Top 10 places in the US
px.bar(location_usa_group.iloc[:10,:1], text_auto=True,title='Top 10 locations where most layoffs happened in USA')
# Out:
# <div>                            <div id="68885f92-4f67-4962-b81f-9e2a212eeed8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68885f92-4f67-4962-b81f-9e2a212eeed8")) {                    Plotly.newPlot(                        "68885f92-4f67-4962-b81f-9e2a212eeed8",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_laid_off<br>location=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_laid_off","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"total_laid_off","offsetgroup":"total_laid_off","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["SF Bay Area","Seattle","New York City","Austin","Boston","Los Angeles","Chicago","Boise","San Diego","Phoenix"],"xaxis":"x","y":[209618.0,54554.0,37457.0,33583.0,19372.0,11317.0,9375.0,7275.0,6140.0,5681.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width ...

# %% [markdown]
# ## Top 10 locations where most layoffs happened in India

# %%
px.bar(df[df.country == "India"].groupby(['location']).sum().sort_values(['total_laid_off'],ascending=False).iloc[:10,:1], text_auto=True,title='Top locations where most layoffs happened in India')
# Out:
# <div>                            <div id="b6ae477d-7583-4ede-9885-8fe6636c7a75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6ae477d-7583-4ede-9885-8fe6636c7a75")) {                    Plotly.newPlot(                        "b6ae477d-7583-4ede-9885-8fe6636c7a75",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_laid_off<br>location=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_laid_off","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"total_laid_off","offsetgroup":"total_laid_off","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bengaluru","Gurugram","Mumbai","Noida","New Delhi","Chennai","Ahmedabad","Kolkata","Indore","Pune"],"xaxis":"x","y":[30907.0,7766.0,7125.0,5170.0,2677.0,1365.0,500.0,125.0,75.0,30.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillm ...

# %% [markdown]
# ## Relationship between funds and layoffs

# %%
df["funds_raised"].corr(df["total_laid_off"])
px.line(df,x='total_laid_off',y='funds_raised',hover_name='company')
px.line(df,x='funds_raised', y='total_laid_off',hover_name='company')
# Out:
# 0.11213809375286488
# <div>                            <div id="0d58dca1-2551-4551-89e7-fbd30ead0396" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d58dca1-2551-4551-89e7-fbd30ead0396")) {                    Plotly.newPlot(                        "0d58dca1-2551-4551-89e7-fbd30ead0396",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>total_laid_off=%{x}<br>funds_raised=%{y}<extra></extra>","hovertext":["Drata","Moov","FreightWaves","F5","Olo","Healthy.io","Reverb","Luminar","Notable Labs","CarTrawler","ApplyBoard","Aakash","IBM","Runtastic","Microsoft","Amperity","Udemy","Mobileye","InsurStaq.ai","Nori","WeTransfer","Goop","Motif Foodworks","ChargePoint","Fly.io","Lyft","ABL","Matter Labs","Dozee","Dunzo","Character.ai","Brave","Apple","IBM","Tome Biosciences","Velo3D","Kenko Health","Received","Sandvine","Redfin","Kaiyo","Skip the Dishes","Five9","ReshaMandi","GoPro","Localize","Paper","Retention.com","Loop","Regrow Ag","AppLovin","Inuitive","Formlabs","Mister Spex","PacketFabric","Sampler","Sonos","Grail","DayTwo","Quizac","Tally","Cisco","Branch.io","iCIMS","Ready Robotics","Fastly","Eventbrite","LegalZoom","Axios Media","Mobius Motors","Teradata","Infineon","Jam City","Dell","ShareChat","Intel","Rad Power Bikes","Bungie","Delivery Hero","Match Group","NerdWallet","Moxion Power","OrCam","Pocket FM","WayCool","Webflow","Humble Games","Cohere","Bluelearn","Magic Leap","Mercari U.S.","Aqua Security","EverC","Lex","ON","Kaspersky","Unbounce","SolarEdge","Salesforce","Spotify","SadaPay","MoxiWorks","Intuit","Redbox","CyberProof","UIPath","UKG","OpenText","Microsoft","Unacademy","Koo","Lightricks","Upside Foods","Sightful","Cint","Ninja Van","Priceline","RealPage","Planet","Moxion Power","eBay","Perion","BeReal","Flutterwave","Ginkgo Bioworks","Trade Republic","Ginkgo Bioworks","Bluevine","ReshaMandi","Emma Sleep","Moovit","Wex","PayPal","Rapyd","C2FO","Fisker","Chegg","Stackpath","Unit","LOOP","Care/of","Running Tide","Satellogic","Cypress.io","Medtronic","Bytedance","Paxos","SCiFi Foods","VRChat","Ladenzeile","Paytm","Kissflow","Copia","Revel","Simpl","Oda","Pagaya","Aleph Farms","MoonPay","Yext","Microsoft","OrCam","Google","Tropic","Gro Intelligence","Jasper Health","FlightStats","ICANN","Walnut","Fisker","Funding Circle","Glovo","Lucid Motors","Satellogic","Foursquare","Guild","Cue Health","Silo","TikTok","Joonko","Toshiba","Wefox","Replit","Gopuff","Karhoo","SeekOut","Atmosphere","Singularity 6","Mainvest","Indeed","Motional","Rivian","Google","Symend","Vacasa","Sight Diagnostics","PrepLadder","Simpl","Arkane Studios","Brilliant","Kinaxis","Hopin","Enovix","Cue Health","Rivian","Luminar","Sprinklr","Bakkt","Peloton","Cabify","Google","Assurance","Sproutt","Tesla","RiseUp","Akili Interactive","Google","Getir","Ola","Ninja Van","ComplYant","Fisker","HealthifyMe","True Anomaly","Grin","Expedia","Freenome","Heureka Group","98point6","OutSystems","Homie","The Good Glamm Group","Showpad","Stability AI","Pax8","ConnectWise","Google","Rivian","Take-Two","Tome","Tesla","Criteo","Glovo","TikTok","Fabric","Hinge Health","Zoe","Cornershop","Scaler","Checkr","Intel","Trendsales","Singularity 6","Fission","Bolt.Earth","Apple","Agility Robotics","Lightspeed Commerce","Ghost Autonomy","Vivian Health","Amazon","CoRover","Kaseya","New Relic","Yummly","Byju's","Lentra","Thepeer","Osso VR","Identiq","Ranger Insurance","Rezi","ChowNow","Synctera","GoPro","Dell","Verily","Cybereason","ShopBack","Orbotech","Airmeet","Singular Genomics","Longi","Flock Freight","Chipper Cash","Blueboard","Ancestry","Textio","Stash","Phantom Auto","IBM","Deadspin","Niche","Inscribe","Turnitin","Totango","Sorare","Meta","PlanetScale","MessageBird","Form Energy","Verbit","Edgio","Melio","Our Next Energy","Project Ronin","Pristyn Car ...
# <div>                            <div id="fffe2718-db2e-4fa3-8fa0-a86d510dbf8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fffe2718-db2e-4fa3-8fa0-a86d510dbf8e")) {                    Plotly.newPlot(                        "fffe2718-db2e-4fa3-8fa0-a86d510dbf8e",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>funds_raised=%{x}<br>total_laid_off=%{y}<extra></extra>","hovertext":["Drata","Moov","FreightWaves","F5","Olo","Healthy.io","Reverb","Luminar","Notable Labs","CarTrawler","ApplyBoard","Aakash","IBM","Runtastic","Microsoft","Amperity","Udemy","Mobileye","InsurStaq.ai","Nori","WeTransfer","Goop","Motif Foodworks","ChargePoint","Fly.io","Lyft","ABL","Matter Labs","Dozee","Dunzo","Character.ai","Brave","Apple","IBM","Tome Biosciences","Velo3D","Kenko Health","Received","Sandvine","Redfin","Kaiyo","Skip the Dishes","Five9","ReshaMandi","GoPro","Localize","Paper","Retention.com","Loop","Regrow Ag","AppLovin","Inuitive","Formlabs","Mister Spex","PacketFabric","Sampler","Sonos","Grail","DayTwo","Quizac","Tally","Cisco","Branch.io","iCIMS","Ready Robotics","Fastly","Eventbrite","LegalZoom","Axios Media","Mobius Motors","Teradata","Infineon","Jam City","Dell","ShareChat","Intel","Rad Power Bikes","Bungie","Delivery Hero","Match Group","NerdWallet","Moxion Power","OrCam","Pocket FM","WayCool","Webflow","Humble Games","Cohere","Bluelearn","Magic Leap","Mercari U.S.","Aqua Security","EverC","Lex","ON","Kaspersky","Unbounce","SolarEdge","Salesforce","Spotify","SadaPay","MoxiWorks","Intuit","Redbox","CyberProof","UIPath","UKG","OpenText","Microsoft","Unacademy","Koo","Lightricks","Upside Foods","Sightful","Cint","Ninja Van","Priceline","RealPage","Planet","Moxion Power","eBay","Perion","BeReal","Flutterwave","Ginkgo Bioworks","Trade Republic","Ginkgo Bioworks","Bluevine","ReshaMandi","Emma Sleep","Moovit","Wex","PayPal","Rapyd","C2FO","Fisker","Chegg","Stackpath","Unit","LOOP","Care/of","Running Tide","Satellogic","Cypress.io","Medtronic","Bytedance","Paxos","SCiFi Foods","VRChat","Ladenzeile","Paytm","Kissflow","Copia","Revel","Simpl","Oda","Pagaya","Aleph Farms","MoonPay","Yext","Microsoft","OrCam","Google","Tropic","Gro Intelligence","Jasper Health","FlightStats","ICANN","Walnut","Fisker","Funding Circle","Glovo","Lucid Motors","Satellogic","Foursquare","Guild","Cue Health","Silo","TikTok","Joonko","Toshiba","Wefox","Replit","Gopuff","Karhoo","SeekOut","Atmosphere","Singularity 6","Mainvest","Indeed","Motional","Rivian","Google","Symend","Vacasa","Sight Diagnostics","PrepLadder","Simpl","Arkane Studios","Brilliant","Kinaxis","Hopin","Enovix","Cue Health","Rivian","Luminar","Sprinklr","Bakkt","Peloton","Cabify","Google","Assurance","Sproutt","Tesla","RiseUp","Akili Interactive","Google","Getir","Ola","Ninja Van","ComplYant","Fisker","HealthifyMe","True Anomaly","Grin","Expedia","Freenome","Heureka Group","98point6","OutSystems","Homie","The Good Glamm Group","Showpad","Stability AI","Pax8","ConnectWise","Google","Rivian","Take-Two","Tome","Tesla","Criteo","Glovo","TikTok","Fabric","Hinge Health","Zoe","Cornershop","Scaler","Checkr","Intel","Trendsales","Singularity 6","Fission","Bolt.Earth","Apple","Agility Robotics","Lightspeed Commerce","Ghost Autonomy","Vivian Health","Amazon","CoRover","Kaseya","New Relic","Yummly","Byju's","Lentra","Thepeer","Osso VR","Identiq","Ranger Insurance","Rezi","ChowNow","Synctera","GoPro","Dell","Verily","Cybereason","ShopBack","Orbotech","Airmeet","Singular Genomics","Longi","Flock Freight","Chipper Cash","Blueboard","Ancestry","Textio","Stash","Phantom Auto","IBM","Deadspin","Niche","Inscribe","Turnitin","Totango","Sorare","Meta","PlanetScale","MessageBird","Form Energy","Verbit","Edgio","Melio","Our Next Energy","Project Ronin","Pristyn Car ...

# %%
px.scatter(df,x='funds_raised', y='total_laid_off',hover_name='company')
px.scatter(df,x='total_laid_off',y='funds_raised',hover_name='company')
# Out:
# <div>                            <div id="d3c0e834-bd6d-414a-85f2-8b790a60c4ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3c0e834-bd6d-414a-85f2-8b790a60c4ab")) {                    Plotly.newPlot(                        "d3c0e834-bd6d-414a-85f2-8b790a60c4ab",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>funds_raised=%{x}<br>total_laid_off=%{y}<extra></extra>","hovertext":["Drata","Moov","FreightWaves","F5","Olo","Healthy.io","Reverb","Luminar","Notable Labs","CarTrawler","ApplyBoard","Aakash","IBM","Runtastic","Microsoft","Amperity","Udemy","Mobileye","InsurStaq.ai","Nori","WeTransfer","Goop","Motif Foodworks","ChargePoint","Fly.io","Lyft","ABL","Matter Labs","Dozee","Dunzo","Character.ai","Brave","Apple","IBM","Tome Biosciences","Velo3D","Kenko Health","Received","Sandvine","Redfin","Kaiyo","Skip the Dishes","Five9","ReshaMandi","GoPro","Localize","Paper","Retention.com","Loop","Regrow Ag","AppLovin","Inuitive","Formlabs","Mister Spex","PacketFabric","Sampler","Sonos","Grail","DayTwo","Quizac","Tally","Cisco","Branch.io","iCIMS","Ready Robotics","Fastly","Eventbrite","LegalZoom","Axios Media","Mobius Motors","Teradata","Infineon","Jam City","Dell","ShareChat","Intel","Rad Power Bikes","Bungie","Delivery Hero","Match Group","NerdWallet","Moxion Power","OrCam","Pocket FM","WayCool","Webflow","Humble Games","Cohere","Bluelearn","Magic Leap","Mercari U.S.","Aqua Security","EverC","Lex","ON","Kaspersky","Unbounce","SolarEdge","Salesforce","Spotify","SadaPay","MoxiWorks","Intuit","Redbox","CyberProof","UIPath","UKG","OpenText","Microsoft","Unacademy","Koo","Lightricks","Upside Foods","Sightful","Cint","Ninja Van","Priceline","RealPage","Planet","Moxion Power","eBay","Perion","BeReal","Flutterwave","Ginkgo Bioworks","Trade Republic","Ginkgo Bioworks","Bluevine","ReshaMandi","Emma Sleep","Moovit","Wex","PayPal","Rapyd","C2FO","Fisker","Chegg","Stackpath","Unit","LOOP","Care/of","Running Tide","Satellogic","Cypress.io","Medtronic","Bytedance","Paxos","SCiFi Foods","VRChat","Ladenzeile","Paytm","Kissflow","Copia","Revel","Simpl","Oda","Pagaya","Aleph Farms","MoonPay","Yext","Microsoft","OrCam","Google","Tropic","Gro Intelligence","Jasper Health","FlightStats","ICANN","Walnut","Fisker","Funding Circle","Glovo","Lucid Motors","Satellogic","Foursquare","Guild","Cue Health","Silo","TikTok","Joonko","Toshiba","Wefox","Replit","Gopuff","Karhoo","SeekOut","Atmosphere","Singularity 6","Mainvest","Indeed","Motional","Rivian","Google","Symend","Vacasa","Sight Diagnostics","PrepLadder","Simpl","Arkane Studios","Brilliant","Kinaxis","Hopin","Enovix","Cue Health","Rivian","Luminar","Sprinklr","Bakkt","Peloton","Cabify","Google","Assurance","Sproutt","Tesla","RiseUp","Akili Interactive","Google","Getir","Ola","Ninja Van","ComplYant","Fisker","HealthifyMe","True Anomaly","Grin","Expedia","Freenome","Heureka Group","98point6","OutSystems","Homie","The Good Glamm Group","Showpad","Stability AI","Pax8","ConnectWise","Google","Rivian","Take-Two","Tome","Tesla","Criteo","Glovo","TikTok","Fabric","Hinge Health","Zoe","Cornershop","Scaler","Checkr","Intel","Trendsales","Singularity 6","Fission","Bolt.Earth","Apple","Agility Robotics","Lightspeed Commerce","Ghost Autonomy","Vivian Health","Amazon","CoRover","Kaseya","New Relic","Yummly","Byju's","Lentra","Thepeer","Osso VR","Identiq","Ranger Insurance","Rezi","ChowNow","Synctera","GoPro","Dell","Verily","Cybereason","ShopBack","Orbotech","Airmeet","Singular Genomics","Longi","Flock Freight","Chipper Cash","Blueboard","Ancestry","Textio","Stash","Phantom Auto","IBM","Deadspin","Niche","Inscribe","Turnitin","Totango","Sorare","Meta","PlanetScale","MessageBird","Form Energy","Verbit","Edgio","Melio","Our Next Energy","Project Ronin","Pristyn Car ...
# <div>                            <div id="a5f7752e-be2c-4ace-8e58-676567a7969f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5f7752e-be2c-4ace-8e58-676567a7969f")) {                    Plotly.newPlot(                        "a5f7752e-be2c-4ace-8e58-676567a7969f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>total_laid_off=%{x}<br>funds_raised=%{y}<extra></extra>","hovertext":["Drata","Moov","FreightWaves","F5","Olo","Healthy.io","Reverb","Luminar","Notable Labs","CarTrawler","ApplyBoard","Aakash","IBM","Runtastic","Microsoft","Amperity","Udemy","Mobileye","InsurStaq.ai","Nori","WeTransfer","Goop","Motif Foodworks","ChargePoint","Fly.io","Lyft","ABL","Matter Labs","Dozee","Dunzo","Character.ai","Brave","Apple","IBM","Tome Biosciences","Velo3D","Kenko Health","Received","Sandvine","Redfin","Kaiyo","Skip the Dishes","Five9","ReshaMandi","GoPro","Localize","Paper","Retention.com","Loop","Regrow Ag","AppLovin","Inuitive","Formlabs","Mister Spex","PacketFabric","Sampler","Sonos","Grail","DayTwo","Quizac","Tally","Cisco","Branch.io","iCIMS","Ready Robotics","Fastly","Eventbrite","LegalZoom","Axios Media","Mobius Motors","Teradata","Infineon","Jam City","Dell","ShareChat","Intel","Rad Power Bikes","Bungie","Delivery Hero","Match Group","NerdWallet","Moxion Power","OrCam","Pocket FM","WayCool","Webflow","Humble Games","Cohere","Bluelearn","Magic Leap","Mercari U.S.","Aqua Security","EverC","Lex","ON","Kaspersky","Unbounce","SolarEdge","Salesforce","Spotify","SadaPay","MoxiWorks","Intuit","Redbox","CyberProof","UIPath","UKG","OpenText","Microsoft","Unacademy","Koo","Lightricks","Upside Foods","Sightful","Cint","Ninja Van","Priceline","RealPage","Planet","Moxion Power","eBay","Perion","BeReal","Flutterwave","Ginkgo Bioworks","Trade Republic","Ginkgo Bioworks","Bluevine","ReshaMandi","Emma Sleep","Moovit","Wex","PayPal","Rapyd","C2FO","Fisker","Chegg","Stackpath","Unit","LOOP","Care/of","Running Tide","Satellogic","Cypress.io","Medtronic","Bytedance","Paxos","SCiFi Foods","VRChat","Ladenzeile","Paytm","Kissflow","Copia","Revel","Simpl","Oda","Pagaya","Aleph Farms","MoonPay","Yext","Microsoft","OrCam","Google","Tropic","Gro Intelligence","Jasper Health","FlightStats","ICANN","Walnut","Fisker","Funding Circle","Glovo","Lucid Motors","Satellogic","Foursquare","Guild","Cue Health","Silo","TikTok","Joonko","Toshiba","Wefox","Replit","Gopuff","Karhoo","SeekOut","Atmosphere","Singularity 6","Mainvest","Indeed","Motional","Rivian","Google","Symend","Vacasa","Sight Diagnostics","PrepLadder","Simpl","Arkane Studios","Brilliant","Kinaxis","Hopin","Enovix","Cue Health","Rivian","Luminar","Sprinklr","Bakkt","Peloton","Cabify","Google","Assurance","Sproutt","Tesla","RiseUp","Akili Interactive","Google","Getir","Ola","Ninja Van","ComplYant","Fisker","HealthifyMe","True Anomaly","Grin","Expedia","Freenome","Heureka Group","98point6","OutSystems","Homie","The Good Glamm Group","Showpad","Stability AI","Pax8","ConnectWise","Google","Rivian","Take-Two","Tome","Tesla","Criteo","Glovo","TikTok","Fabric","Hinge Health","Zoe","Cornershop","Scaler","Checkr","Intel","Trendsales","Singularity 6","Fission","Bolt.Earth","Apple","Agility Robotics","Lightspeed Commerce","Ghost Autonomy","Vivian Health","Amazon","CoRover","Kaseya","New Relic","Yummly","Byju's","Lentra","Thepeer","Osso VR","Identiq","Ranger Insurance","Rezi","ChowNow","Synctera","GoPro","Dell","Verily","Cybereason","ShopBack","Orbotech","Airmeet","Singular Genomics","Longi","Flock Freight","Chipper Cash","Blueboard","Ancestry","Textio","Stash","Phantom Auto","IBM","Deadspin","Niche","Inscribe","Turnitin","Totango","Sorare","Meta","PlanetScale","MessageBird","Form Energy","Verbit","Edgio","Melio","Our Next Energy","Project Ronin","Pristyn Car ...

# %% [markdown]
# ### As we can see in the above plot, there is no dependency b/w funds & lay offs

# %% [markdown]
# ## In which stage of the company had the most lay offs?

# %%
df["stage"].unique()
# Out:
# array(['Series C', 'Series B', 'Private Equity', 'Post-IPO', 'Series D',
#        'Acquired', 'Seed', 'Unknown', 'Series A', 'Series E', 'Series F',
#        'Subsidiary', 'Series H', 'Series G', 'Series J', 'Series I', nan],
#       dtype=object)

# %%
df.groupby(["stage"]).total_laid_off.sum()
# Out:
# stage
# Acquired           63970.0
# Post-IPO          370999.0
# Private Equity     11015.0
# Seed                2159.0
# Series A            8255.0
# Series B           29306.0
# Series C           25311.0
# Series D           25186.0
# Series E           22187.0
# Series F           13613.0
# Series G            4452.0
# Series H            8197.0
# Series I            2855.0
# Series J            3750.0
# Subsidiary          7214.0
# Unknown            65125.0
# Name: total_laid_off, dtype: float64

# %%
px.bar(df.groupby(["stage"]).total_laid_off.sum().sort_values(ascending=False),title='Layoffs & company stage',
       text_auto=True,orientation='h'
      )
# Out:
# <div>                            <div id="3ca4278b-aec2-425e-993a-9681abe40e7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ca4278b-aec2-425e-993a-9681abe40e7b")) {                    Plotly.newPlot(                        "3ca4278b-aec2-425e-993a-9681abe40e7b",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_laid_off<br>value=%{x}<br>stage=%{y}<extra></extra>","legendgroup":"total_laid_off","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"total_laid_off","offsetgroup":"total_laid_off","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[370999.0,65125.0,63970.0,29306.0,25311.0,25186.0,22187.0,13613.0,11015.0,8255.0,8197.0,7214.0,4452.0,3750.0,2855.0,2159.0],"xaxis":"x","y":["Post-IPO","Unknown","Acquired","Series B","Series C","Series D","Series E","Series F","Private Equity","Series A","Series H","Subsidiary","Series G","Series J","Series I","Seed"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %% [markdown]
# ## Which industry had the most layoffs?

# %%
df['industry'] = df['industry'].replace('https://www.calcalistech.com/ctechnews/article/rysmrkfua', 'calcalistech')

# %%
top_industry_wise = df.groupby(['industry']).total_laid_off.sum().sort_values(ascending=False)
top_industry_wise
# Out:
# industry
# Retail            71556.0
# Consumer          69941.0
# Transportation    60668.0
# Other             60636.0
# Hardware          53870.0
# Finance           49042.0
# Food              48023.0
# Healthcare        38011.0
# Travel            23235.0
# Infrastructure    20614.0
# Education         19642.0
# Real Estate       19450.0
# Sales             15248.0
# Crypto            13683.0
# Marketing         12654.0
# Media             10581.0
# HR                10397.0
# Data              10055.0
# Security           9948.0
# Fitness            9841.0
# Manufacturing      7350.0
# Support            6381.0
# Logistics          5372.0
# Recruiting         5170.0
# Construction       3863.0
# Energy             3816.0
# Product            2108.0
# Aerospace          1472.0
# Legal               966.0
# AI                  288.0
# calcalistech          0.0
# Name: total_laid_off, dtype: float64

# %%
top_industry_wise.shape
# Out:
# (31,)

# %%
px.bar(x=top_industry_wise.index,y=top_industry_wise.values,text_auto=True,labels={'x': 'Industry', 'y':'Layoffs'},
      title='Industry vs Layoffs')
# Out:
# <div>                            <div id="d08616d2-16d0-4115-b5df-1d3cef5e00f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d08616d2-16d0-4115-b5df-1d3cef5e00f9")) {                    Plotly.newPlot(                        "d08616d2-16d0-4115-b5df-1d3cef5e00f9",                        [{"alignmentgroup":"True","hovertemplate":"Industry=%{x}<br>Layoffs=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Retail","Consumer","Transportation","Other","Hardware","Finance","Food","Healthcare","Travel","Infrastructure","Education","Real Estate","Sales","Crypto","Marketing","Media","HR","Data","Security","Fitness","Manufacturing","Support","Logistics","Recruiting","Construction","Energy","Product","Aerospace","Legal","AI","calcalistech"],"xaxis":"x","y":[71556.0,69941.0,60668.0,60636.0,53870.0,49042.0,48023.0,38011.0,23235.0,20614.0,19642.0,19450.0,15248.0,13683.0,12654.0,10581.0,10397.0,10055.0,9948.0,9841.0,7350.0,6381.0,5372.0,5170.0,3863.0,3816.0,2108.0,1472.0,966.0,288.0,0.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"ty ...

# %% [markdown]
# ## Total layoffs year-wise

# %%
total_laid_year_wise = df.groupby(["Year"]).total_laid_off.sum()
total_laid_year_wise
# Out:
# Year
# 2020     80998.0
# 2021     15823.0
# 2022    165269.0
# 2023    264220.0
# 2024    137606.0
# Name: total_laid_off, dtype: float64

# %%
px.bar(x=total_laid_year_wise.index,y=total_laid_year_wise.values,
      labels={"x":"Year","y":"Layoffs"},
       text_auto=True,
       title="Year-wise layoffs"
      )
# Out:
# <div>                            <div id="d945e8dc-70a3-484a-af27-3cc8c37bb2b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d945e8dc-70a3-484a-af27-3cc8c37bb2b6")) {                    Plotly.newPlot(                        "d945e8dc-70a3-484a-af27-3cc8c37bb2b6",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Layoffs=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["2020","2021","2022","2023","2024"],"xaxis":"x","y":[80998.0,15823.0,165269.0,264220.0,137606.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpol ...

# %% [markdown]
# ## Year wise layoffs according to country

# %%
total_laid_year_country_wise = df.groupby(["Year","country"]).total_laid_off.sum()
total_laid_year_country_wise
# Out:
# Year  country
# 2020  Australia           126.0
#       Brazil             3341.0
#       Bulgaria            120.0
#       Canada             1211.0
#       China                 0.0
#                          ...
# 2024  Spain                76.0
#       Sweden              200.0
#       United Kingdom     5390.0
#       United States     98607.0
#       Uruguay             104.0
# Name: total_laid_off, Length: 160, dtype: float64

# %%
len(df.country.unique()) # We have 55 countries
# Out:
# 63

# %%
total_laid_year_country_wise_year = []
total_laid_year_country_wise_country = []
for i,j in total_laid_year_country_wise.index:
    total_laid_year_country_wise_year.append(i)
    total_laid_year_country_wise_country.append(j)

# %%
total_laid_year_country_wise2 = pd.DataFrame({
    "Year": total_laid_year_country_wise_year,
    "Country": total_laid_year_country_wise_country,
    "total_laid_off": total_laid_year_country_wise.values 
})

# %%
total_laid_year_country_wise2
# Out:
#      Year         Country  total_laid_off
# 0    2020       Australia           126.0
# 1    2020          Brazil          3341.0
# 2    2020        Bulgaria           120.0
# 3    2020          Canada          1211.0
# 4    2020           China             0.0
# ..    ...             ...             ...
# 155  2024           Spain            76.0
# 156  2024          Sweden           200.0
# 157  2024  United Kingdom          5390.0
# 158  2024   United States         98607.0
# 159  2024         Uruguay           104.0
#
# [160 rows x 3 columns]

# %%
total_laid_year_country_wise2.sort_values(["Year","total_laid_off"],ascending=False,inplace=True)

# %%
px.bar(total_laid_year_country_wise2,x='Year',y='total_laid_off',color='Country',text='Country',
      title='Year wise layoffs according to country'
      )
# Out:
# <div>                            <div id="920c5ea0-5ff3-42f2-a541-afa705c7d887" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("920c5ea0-5ff3-42f2-a541-afa705c7d887")) {                    Plotly.newPlot(                        "920c5ea0-5ff3-42f2-a541-afa705c7d887",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"text":["United States","United States","United States","United States","United States"],"textposition":"auto","x":["2024","2023","2022","2021","2020"],"xaxis":"x","y":[98607.0,180001.0,109895.0,9470.0,50385.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"text":["Germany","Germany","Germany","Germany","Germany"],"textposition":"auto","x":["2024","2023","2022","2021","2020"],"xaxis":"x","y":[10500.0,13128.0,3607.0,387.0,531.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"text":["India","India","India","India","India"],"textposition":"auto","x":["2024","2023","2022","2021","2020"],"xaxis":"x","y":[8125.0,16398.0,14224.0,4080.0,12932.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"United Kingdom","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"United Kingdom","offsetgroup":"United Kingdom","orientation":"v","showlegend":true,"text":["United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom"],"textposition":"auto","x":["2024","2023","2022","2021","2020"],"xaxis":"x","y":[5390.0,10402.0,3099.0,20.0,1858.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Japan","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"text":["Japan","Japan"],"textposition":"auto","x":["2024","2023"],"xaxis":"x","y":[4000.0,165.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"text":["Canada","Canada","Canada","Canada","Canada"],"textposition":"auto","x":["2024","2023","2022","2021","2020"],"xaxis":"x","y":[2574.0,4656.0,3936.0,45.0,1211.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Israel","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Israel","offsetgroup":"Israel","orientation":"v","showlegend":true,"text":["Israel","Israel","Israel","Israel"],"textposition":"auto","x":["2024","2023","2022","2020"],"xaxis":"x","y":[2547.0,1468.0,2734.0,224.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{text}<br>Year=%{x}<br>total_laid_off=%{y}<extra></extra>","legendgroup":"Kenya","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Kenya","offsetgroup":"Kenya","orientation":"v","showlegend ...
